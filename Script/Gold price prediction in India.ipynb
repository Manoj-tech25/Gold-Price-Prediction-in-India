# %% [markdown]
# # Import Yfinance

# %%
import yfinance as yf

# %% [markdown]
# # Data collecting

# %%
Usd_inr = yf.download('USDINR=X',start = '2024-01-01',end='2024-12-31',interval='1wk')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(Usd_inr)
# Out:
# pandas.core.frame.DataFrame

# %%
Usd_inr.head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker       USDINR=X   USDINR=X   USDINR=X   USDINR=X USDINR=X
# Date
# 2024-01-01  83.240601  83.360298  83.035004  83.248596        0
# 2024-01-08  83.076103  83.189697  82.779099  83.191101        0
# 2024-01-15  83.160599  83.230797  82.809998  82.872101        0
# 2024-01-22  83.146103  83.222504  81.513702  83.124702        0
# 2024-01-29  82.927597  83.212601  82.815002  83.121300        0

# %%
Usd_inr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 53 entries, 2024-01-01 to 2024-12-30
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, USDINR=X)   53 non-null     float64
#  1   (High, USDINR=X)    53 non-null     float64
#  2   (Low, USDINR=X)     53 non-null     float64
#  3   (Open, USDINR=X)    53 non-null     float64
#  4   (Volume, USDINR=X)  53 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.5 KB

# %%
Usd_inr.reset_index(inplace=True)

# %%
Usd_inr= Usd_inr[['Date','Close']]
Usd_inr.columns = ['Date','USD_INR']

# %%
Usd_inr
# Out:
#          Date    USD_INR
# 0  2024-01-01  83.240601
# 1  2024-01-08  83.076103
# 2  2024-01-15  83.160599
# 3  2024-01-22  83.146103
# 4  2024-01-29  82.927597
# 5  2024-02-05  82.985298
# 6  2024-02-12  83.009598
# 7  2024-02-19  82.872299
# 8  2024-02-26  82.910400
# 9  2024-03-04  82.752296
# 10 2024-03-11  82.965599
# 11 2024-03-18  83.226601
# 12 2024-03-25  83.392998
# 13 2024-04-01  83.477798
# 14 2024-04-08  83.349297
# 15 2024-04-15  83.544998
# 16 2024-04-22  83.301804
# 17 2024-04-29  83.406303
# 18 2024-05-06  83.459396
# 19 2024-05-13  83.470100
# 20 2024-05-20  83.286400
# 21 2024-05-27  83.320900
# 22 2024-06-03  83.473099
# 23 2024-06-10  83.522102
# 24 2024-06-17  83.601601
# 25 2024-06-24  83.450897
# 26 2024-07-01  83.493401
# 27 2024-07-08  83.518501
# 28 2024-07-15  83.674301
# 29 2024-07-22  83.744400
# 30 2024-07-29  83.743896
# 31 2024-08-05  83.988998
# 32 2024-08-12  83.948303
# 33 2024-08-19  83.940598
# 34 2024-08-26  83.895103
# 35 2024-09-02  83.983597
# ...

# %%
import pandas as pd
Gold_dataset=pd.read_csv('Gold Futures Historical Data.csv')

# %%
Gold_dataset.head()
# Out:
#          Date     Price      Open      High       Low     Vol. Change %
# 0  12/31/2024  2,641.00  2,620.00  2,642.00  2,614.30   86.29K    0.87%
# 1  12/30/2024  2,618.10  2,636.10  2,640.70  2,608.40  110.92K   -0.01%
# 2  12/27/2024  2,618.40  2,639.70  2,639.70  2,612.10    0.64K   -0.83%
# 3  12/26/2024  2,640.30  2,623.30  2,642.40  2,622.80    1.40K    0.67%
# 4  12/24/2024  2,622.80  2,616.50  2,622.70  2,612.50    0.42K    0.28%

# %%
Gold_dataset = Gold_dataset[['Date','Price']]

# %%
Gold_dataset
# Out:
#            Date     Price
# 0    12/31/2024  2,641.00
# 1    12/30/2024  2,618.10
# 2    12/27/2024  2,618.40
# 3    12/26/2024  2,640.30
# 4    12/24/2024  2,622.80
# ..          ...       ...
# 252  01/08/2024  2,033.50
# 253  01/05/2024  2,049.80
# 254  01/04/2024  2,050.00
# 255  01/03/2024  2,042.80
# 256  01/02/2024  2,073.40
#
# [257 rows x 2 columns]

# %%
Usd_inr['Date'] = pd.to_datetime(Usd_inr['Date'])
Gold_dataset['Date'] = pd.to_datetime(Gold_dataset['Date'])

# %%
Gold_price = pd.merge(Usd_inr, Gold_dataset, on='Date')

# %%
Gold_price
# Out:
#          Date    USD_INR   Price
# 0  2024-01-08  83.076103  2033.5
# 1  2024-01-15  83.160599  2030.2
# 2  2024-01-22  83.146103  2022.2
# 3  2024-01-29  82.927597  2025.4
# 4  2024-02-05  82.985298  2032.9
# 5  2024-02-12  83.009598  2023.4
# 6  2024-02-19  82.872299  2039.8
# 7  2024-02-26  82.910400  2029.1
# 8  2024-03-04  82.752296  2126.3
# 9  2024-03-11  82.965599  2188.6
# 10 2024-03-18  83.226601  2164.3
# 11 2024-03-25  83.392998  2176.4
# 12 2024-04-01  83.477798  2245.9
# 13 2024-04-08  83.349297  2339.0
# 14 2024-04-15  83.544998  2370.9
# 15 2024-04-22  83.301804  2334.6
# 16 2024-04-29  83.406303  2357.7
# 17 2024-05-06  83.459396  2331.2
# 18 2024-05-13  83.470100  2343.0
# 19 2024-05-20  83.286400  2438.5
# 20 2024-05-27  83.320900  2356.5
# 21 2024-06-03  83.473099  2357.5
# 22 2024-06-10  83.522102  2315.1
# 23 2024-06-17  83.601601  2316.9
# 24 2024-06-24  83.450897  2332.4
# 25 2024-07-01  83.493401  2338.9
# 26 2024-07-08  83.518501  2363.5
# ...

# %%
Gold_price['Price'] = Gold_price['Price'].replace(',','',regex=True).astype(float)

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.regplot(x='USD_INR',y='Price', data=Gold_price)
# Out:
# <Axes: xlabel='USD_INR', ylabel='Price'>

# %%
x = Gold_price[['USD_INR']]
y = Gold_price[['Price']]

# %%
import sys
sys.path.append(r"C:\Users\Manojkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages")

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((45, 1), (6, 1))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_test_scaled
# Out:
# array([[ 1.21889496],
#        [ 0.61529693],
#        [ 1.51484361],
#        [-0.31474683],
#        [-0.3561693 ],
#        [ 0.40973527]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
regression.coef_
# Out:
# array([[177.10866071]])

# %%
regression.intercept_
# Out:
# array([2379.13555556])

# %%
m = regression.coef_[0][0]
c = regression.intercept_[0]

# %%
m,c
# Out:
# (np.float64(177.10866071295433), np.float64(2379.1355555555556))

# %%
x_train_predict = regression.predict(x_train_scaled)

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_train,x_train_predict,color='r')
plt.xlabel('USDINR')
plt.ylabel('GoldPrice')
plt.show()

# %%
x_test_predict = regression.predict(x_test_scaled)

# %%
x_test_predict
# Out:
# array([[2595.01240936],
#        [2488.10997116],
#        [2647.42747793],
#        [2323.39116565],
#        [2316.054887  ],
#        [2451.70322021]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,x_test_predict)
# Out:
# 10681.947186578553

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_space ={ 'copy_X':[True,False],
              'fit_intercept':[True,False],
              'n_jobs':[1,5,10,15,None],
              'positive':[True,False]}

# %%
search = RandomizedSearchCV(regression,param_space,n_iter=50,cv=5)

# %%
search.fit(x_train,y_train)
# Out:
# C:\Users\Manojkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 40 is smaller than n_iter=50. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\Manojkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
# ...

# %%
search.best_params_
# Out:
# {'positive': True, 'n_jobs': 1, 'fit_intercept': True, 'copy_X': True}

# %%
tuned_model = LinearRegression(positive= True, n_jobs= 1, fit_intercept= True, copy_X = True)

# %%
tuned_model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression(n_jobs=1, positive=True)

# %%
tuned_model.coef_
# Out:
# array([[177.10866071]])

# %%
tuned_model.intercept_
# Out:
# array([2379.13555556])

# %%
import pickle

# %%
pickle.dump(regression,open('regression.pkl','wb'))

# %%
regression_relo = pickle.load(open('regression.pkl','rb'))

# %%
regression_relo.coef_
# Out:
# array([[177.10866071]])

# %%
pickle.dump(scaler,open('Scaler.pkl','wb'))

# %%
import numpy as np
def calculate_GoldPrice(Usd_inr):
    scaled_input = scaler.transform(np.array(Usd_inr).reshape(1,-1))
    return regression.predict(scaled_input)

# %%
calculate_GoldPrice(80)
# Out:
# C:\Users\Manojkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_11976\2836917915.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(regression.predict(scaled_input))
# 1374.955563612493

# %%
# !pip install gradio
# Out:
# ...
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# ...
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import gradio as gr

def calculate_GoldPrice(Usd_inr):
    scaled_input = scaler.transform(np.array([[Usd_inr]]))
    return float(regression.predict(scaled_input))

demo = gr.Interface(fn=calculate_GoldPrice, inputs="number", outputs="number")
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# C:\Users\Manojkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Manojkumar\AppData\Local\Temp\ipykernel_11976\2836917915.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(regression.predict(scaled_input))
# ...

# %%
import gradio as gr

gr.close_all()  # Close all running Gradio interfaces
# Out:
# Closing server running on port: 7860
# Closing server running on port: 7862
# Closing server running on port: 7862
# Closing server running on port: 7860
# Closing server running on port: 7860
# Closing server running on port: 7860
# Closing server running on port: 7860
# Closing server running on port: 7861
# Closing server running on port: 7860
# Closing server running on port: 7860
# Closing server running on port: 7861
# Closing server running on port: 7860
# Closing server running on port: 7861
